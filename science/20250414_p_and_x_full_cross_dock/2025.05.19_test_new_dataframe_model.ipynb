# %%
import harbor.analysis.cross_docking as cd
import pandas as pd

# %%
/data1/choderaj/paynea/asap-datasets/full_cross_dock/chemical_similarity_data/bemis_murcko_clustering/bajorath_cluster_labels.csv
/data1/choderaj/paynea/asap-datasets/full_cross_dock/chemical_similarity_data/bemis_murcko_clustering/csk_cluster_labels.csv
/data1/choderaj/paynea/asap-datasets/full_cross_dock/chemical_similarity_data/bemis_murcko_clustering/default_cluster_labels.csv
/data1/choderaj/paynea/asap-datasets/full_cross_dock/chemical_similarity_data/bemis_murcko_clustering/generic_cluster_labels.csv
/data1/choderaj/paynea/asap-datasets/full_cross_dock/chemical_similarity_data/ecfp_tanimoto/fingerprint_similarities.csv
/data1/choderaj/paynea/asap-datasets/full_cross_dock/chemical_similarity_data/mcs_tanimoto/mcs_tanimoto.csv
/data1/choderaj/paynea/asap-datasets/full_cross_dock/chemical_similarity_data/tanimoto_combo/tanimoto_combo.csv

# %%
key_cols = ["Query_Ligand", "Reference_Ligand"]

# %%
ecfp = cd.DataFrameModel(name="ECFPData", 
                         type=cd.DataFrameType.CHEMICAL_SIMILARITY, 
                         dataframe=pd.read_csv("/data1/choderaj/paynea/asap-datasets/full_cross_dock/chemical_similarity_data/ecfp_tanimoto/fingerprint_similarities.csv"),
                        key_columns = key_cols,
                        param_columns=["radius", "bitsize"])

# %%
mcs_tanimoto = cd.DataFrameModel(name="MCSData",
                                 type=cd.DataFrameType.CHEMICAL_SIMILARITY,
                                 dataframe=pd.read_csv("/data1/choderaj/paynea/asap-datasets/full_cross_dock/chemical_similarity_data/mcs_tanimoto/mcs_tanimoto.csv"),
                                 key_columns = key_cols,)

# %%
mcs_df = pd.read_csv("/data1/choderaj/paynea/asap-datasets/full_cross_dock/chemical_similarity_data/mcs_tanimoto/mcs_tanimoto.csv")

# %%
mcs_df.groupby(key_cols).count()

# %%
grouped_by_key_and_param = mcs_df.groupby(key_cols).count()
(grouped_by_key_and_param > 1).any(axis=1).sum()

# %%
grouped = mcs_df.groupby(key_cols).count()

# %%
grouped[grouped["Tanimoto"] > 1]

# %%
mcs_df.groupby("Type").count()

# %%
mcs_df[(mcs_df["Query_Ligand"] == "AAR-POS-0daf6b7e-1")&(mcs_df["Reference_Ligand"] == "ADA-UCB-6c2cb422-1")]

# %%
filtered_rows = mcs_df[mcs_df.groupby(key_cols).transform(lambda x: (x > 1).any()).any(axis=1)]
