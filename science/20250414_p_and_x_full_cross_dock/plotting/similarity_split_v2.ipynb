# %%
import pandas as pd
from harbor.analysis.cross_docking import Evaluator, DockingDataModel

# %%
df = pd.read_csv("/Users/alexpayne/Scientific_Projects/mers-drug-discovery/sars2-retrospective-analysis/analyzed_results/increasing_similarity_ecfp4_posit_multipose_combined_results.csv")

# %%
evs = {ev for ev in df.Evaluator_Model.unique()}

# %%
len(evs)

# %%
ddm = DockingDataModel.deserialize("/Users/alexpayne/Scientific_Projects/mers-drug-discovery/sars2-retrospective-analysis/analyzed_results/ALL_multipose.parquet")

# %%
ev = Evaluator.from_json_str(evs.pop())

# %%
ev.n_bootstraps = 10
ev.run(ddm)

# %%
data = ev.run_pose_selector(ddm)

# %%
ddm.get_groupby_columns()

# %%
raw = pd.read_parquet("/Users/alexpayne/Scientific_Projects/mers-drug-discovery/sars2-retrospective-analysis/analyzed_results/ALL_multipose.parquet")

# %%
relevant = raw[~raw['PoseData_RMSD'].isna()]

# %%
relevant.groupby(["Query_Ligand", "Reference_Structure", "Pose_ID"]).head(1)
