# %%
import pandas as pd
from pathlib import Path

# %%
# Load the data

# %%
data = Path("/Users/alexpayne/Scientific_Projects/mers-drug-discovery/sars2-retrospective-analysis/ligand_files_20250113")

# %%
tc = data / "tanimoto_combo_p_to_x/tanimoto_combo.csv"
mcs = data / "mcs_tanimoto_p_to_x/mcs_tanimoto.csv"
ecfp = data / "ecfp_tanimoto_p_to_x/fingerprint_similarities.csv"

# %%
tc_df = pd.read_csv(tc)
mcs_df = pd.read_csv(mcs)
ecfp_df = pd.read_csv(ecfp)

# %% [markdown]
# # combine 3 dataframes into a non-redundant dataframe

# %%
pd.merge(tc_df, mcs_df, on=["Reference_Ligand", "Query_Ligand"], how="outer")
# Out:
#           Reference_Ligand        Query_Ligand           Type  Tanimoto_x  \
# 0       AAR-POS-0daf6b7e-1  ADA-UCB-6c2cb422-1  TanimotoCombo    0.306946
# 1       AAR-POS-0daf6b7e-1  ADA-UCB-6c2cb422-1  TanimotoCombo    0.000478
# 2       AAR-POS-0daf6b7e-1  ALP-POS-133e7cd9-2  TanimotoCombo    0.255037
# 3       AAR-POS-0daf6b7e-1  ALP-POS-133e7cd9-2  TanimotoCombo    0.003189
# 4       AAR-POS-0daf6b7e-1  ALP-POS-1cbc2fae-1  TanimotoCombo    0.325542
# ...                    ...                 ...            ...         ...
# 144311  WIL-MOD-03b86a88-6  VLA-UCB-50c39ae8-2  TanimotoCombo    0.407462
# 144312  WIL-MOD-03b86a88-6  VLA-UCB-50c39ae8-7  TanimotoCombo    0.449383
# 144313  WIL-MOD-03b86a88-6  VLA-UCB-50c39ae8-7  TanimotoCombo    0.403336
# 144314  WIL-MOD-03b86a88-6  VLA-UNK-82501c2c-1  TanimotoCombo    0.591204
# 144315  WIL-MOD-03b86a88-6  VLA-UNK-82501c2c-1  TanimotoCombo    0.526617
#
#         Tanimoto_Shape  Tanimoto_Color  Aligned  MCS_Num_Atoms  \
# 0             0.459360        0.154532     True             16
# 1             0.000956        0.000000    False             16
# 2             0.355660        0.154415     True             22
# 3             0.006377        0.000000    False             22
# 4             0.407270        0.243814     True             16
# ...                ...             ...      ...            ...
# 144311        0.561639        0.253285    False             21
# 144312        0.603886        0.294880     True             22
# 144313        0.604563        0.202110    False             22
# 144314        0.699508        0.482900     True             24
# 144315        0.655806        0.397428    False             24
#
#         Total_Num_Atoms  Tanimoto_y
# 0                    66    0.242424
# 1                    66    0.242424
# 2                    93    0.236559
# 3                    93    0.236559
# 4                    75    0.213333
# ...                 ...         ...
# 144311               80    0.262500
# 144312               85    0.258824
# 144313               85    0.258824
# 144314               71    0.338028
# 144315               71    0.338028
#
# [144316 rows x 10 columns]

# %% [markdown]
# # fix the column names to make a less tidy dataframe
