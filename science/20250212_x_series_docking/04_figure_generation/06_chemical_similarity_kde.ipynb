# %% [markdown]
# # the purpose of this notebook is to generate a KDE plot of the chemical similarity of the compounds in the dataset

# %%
import pandas as pd
import numpy as np

# %%
raw_df = pd.read_csv("/Users/alexpayne/Scientific_Projects/mers-drug-discovery/sars2-retrospective-analysis/20250212_p_to_x_posit/20250311_combined_results")

# %% [markdown]
# ## extract just the similarity data

# %%
similarity_df = raw_df.groupby(["Query_Ligand", "Reference_Ligand"]).head(1).reset_index()

# %%
similarity_df
# Out:
#          index  Unnamed: 0        Query_Ligand Reference_Structure  \
# 0            0           0  ERI-UCB-d6de1f3c-2      Mpro-x11810_0A
# 1          110         110  ERI-UCB-d6de1f3c-2      Mpro-x11368_0A
# 2          132         132  ERI-UCB-d6de1f3c-2      Mpro-x12300_0A
# 3          462         462  ERI-UCB-d6de1f3c-2      Mpro-x10834_0A
# 4          704         704  ERI-UCB-d6de1f3c-2      Mpro-x10906_0A
# ...        ...         ...                 ...                 ...
# 66261  5599242     5599242  MAT-POS-e6dd326d-8      Mpro-x11368_0A
# 66262  5599275     5599275  MAT-POS-e6dd326d-8      Mpro-x10575_0A
# 66263  5599286     5599286  MAT-POS-e6dd326d-8      Mpro-x10995_0A
# 66264  5599308     5599308  MAT-POS-e6dd326d-8      Mpro-x11186_0A
# 66265  5599341     5599341  MAT-POS-e6dd326d-8      Mpro-x12300_0A
#
#                           Reference_Ligand_SMILES  \
# 0             c1ccc2c(c1)cncc2NC(=O)Cc3cc(ccn3)Cl
# 1                    Cc1ccncc1NC(=O)Cc2cccc(c2)Br
# ...

# %%
800*800
# Out:
# 640000
