# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv('/Users/alexpayne/Scientific_Projects/asapdiscovery-sars-retrospective/science/20250212_x_series_docking/03_docking_analysis_scripts/test_run_evaluators/similarity_split/results.csv', index_col=0)

# %%
df

# %%
fig = px.line(df, x='Similarity_Threshold', y='Fraction', color='Score')

# %%
fig.show()
